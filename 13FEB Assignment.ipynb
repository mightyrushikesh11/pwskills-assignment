# %% [markdown]
# Q1. Explain why we have to use the Exception class while creating a Custom Exception.
#
# Note: Here Exception class refers to the base class for all the exceptions.
#
# Ans.When creating a custom exception in Python, it is important to inherit from the built-in Exception class.
#
# This is because the Exception class provides the basic functionality required by all exceptions, such as a string representation of the exception, and methods like __str__() and __repr__() that are used to provide a readable description of the exception when it is raised.
#
# By inheriting from the Exception class, we ensure that our custom exception will have all of the necessary properties and methods to function correctly within the Python exception handling system. Additionally, by inheriting from the Exception class, our custom exception can be caught by any code that is set up to catch exceptions of the base Exception class.

# %% [markdown]
# Q2. Write a python program to print Python Exception Hierarchy

# %%
def print_exception_hierarchy(exception_class=BaseException, depth=0):
    print(' ' * depth + exception_class.__name__)
    for subclass in exception_class.__subclasses__():
        print_exception_hierarchy(subclass, depth + 1)

print_exception_hierarchy()
# Out:
# BaseException
#  Exception
#   TypeError
#    FloatOperation
#    MultipartConversionError
#   StopAsyncIteration
#   StopIteration
#   ImportError
#    ModuleNotFoundError
#    ZipImportError
#   OSError
#    ConnectionError
#     BrokenPipeError
#     ConnectionAbortedError
#     ConnectionRefusedError
#     ConnectionResetError
#      RemoteDisconnected
#    BlockingIOError
#    ChildProcessError
#    FileExistsError
#    FileNotFoundError
#    IsADirectoryError
#    NotADirectoryError
#    InterruptedError
#     InterruptedSystemCall
#    PermissionError
#    ProcessLookupError
#    TimeoutError
#    UnsupportedOperation
#    itimer_error
#    herror
#    gaierror
#    SSLError
#     SSLCertVerificationError
#     SSLZeroReturnError
#     SSLWantWriteError
#     SSLWantReadError
#     SSLSyscallError
#     SSLEOFError
#    Error
#     SameFileError
#    SpecialFileError
#    ExecError
#    ReadError
#    URLError
#     HTTPError
#     ContentTooShortError
#    BadGzipFile
# ...

# %% [markdown]
# Q3. What errors are defined in the ArithmeticError class? Explain any two with an example
#
# Ans. ArithmeticError class is a built in class and is a subclass of Exception class.
# The ArithmaticError class have subclass:

# %%
#1.ZeroDivisionErrror: it occurs when we try to divide any number by o.
#EXAMPLE
try:
    1/0
except ZeroDivisionError as e:
    print('try to show the error >>',e)
# Out:
# try to show the error >> division by zero

# %%
#2. OVERFLOWERROR: it occurs when the result of arithmatic operation is too large
#EXAMPLE:

try:
    a= 200**200000
    int(a)
except OverflowError as e:
    print('try to show the error>>',e)

# %% [markdown]
# Q4. Why LookupError class is used? Explain with an example KeyError and IndexError.
#
# Ans.LookupError class is used to identify the Keyerror and Indexerror.
#
# Keyerror raised when key will not present in dictionary and we try to access the value through it.
# Indexerror raised when the index which is trying to access is out of range or not present any element on this specific index.

# %%
#lookuperror
try:
    d={'name':'Rajnish'}
    d['address']
except LookupError as e:
    print('The error is',e)
# Out:
# The error is 'address'

# %%
#Keyerror
try:
    d={'name':'Rajnish'}
    d['address']
except KeyError as e:
    print('The error is',e)
# Out:
# The error is 'address'

# %%
#indexerror
try:
    l=[1,2,3,4]
    l[6]
except IndexError as e:
    print('The error is',e)
# Out:
# The error is list index out of range

# %% [markdown]
# Q5. Explain ImportError. What is ModuleNotFoundError?
#
# Ans.ImportError is raised when an imported module, function, or object cannot be found or loaded by the interpreter.
# Starting with Python 3.6, a more specific subclass of ImportError called ModuleNotFoundError was introduced.

# %%
try:
    import xyz
except ModuleNotFoundError as e:
     print('The error is',e)
# Out:
# The error is No module named 'xyz'

# %% [markdown]
# Q6. List down some best practices for exception handling in python.
#
# ANS. 1.USE ALWAYS A SPECIFIC EXCEPTION
#      2.PRINT ALWAYS A PROPER MESSAGE
#      3.ALWAYS TRY TO LOG  YOUR ERROR
#      4.ALWAYS AVOID TO WRITE THE MULTIPLE EXCEPTION HANDLING
#      5.DOCUMENT ALL THE ERROR
#      6.CLEANUP ALL THE RESOURCES
